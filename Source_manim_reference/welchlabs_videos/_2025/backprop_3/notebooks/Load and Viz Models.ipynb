# %% [markdown]
# ## Load and Viz Models

# %%
import numpy as np
import torch.nn as nn
import torch
import matplotlib.pyplot as plt
import torch.optim as optim
import cv2
from matplotlib.gridspec import GridSpec
from tqdm import tqdm
import os
from torch.utils.data import DataLoader, TensorDataset
from PIL import Image

# %%
from itertools import product
from scipy.spatial import ConvexHull
import warnings

def find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=1000, min_samples_per_region=5):
    """
    Find linear regions (polytopes) created by a ReLU network on a 2D input plane.
    
    Args:
        model: PyTorch model with ReLU activations (like BaarleNet)
        extent: [xmin, xmax, ymin, ymax] defining the input plane bounds
        grid_resolution: Number of points along each axis for sampling
        min_samples_per_region: Minimum points needed to define a region
    
    Returns:
        List of numpy arrays, each containing corner coordinates of a linear region
    """
    
    def get_relu_pattern(model, x):
        """Get the activation pattern (which ReLUs are active) for input x"""
        pattern = []
        current_x = x
        
        with torch.no_grad():
            for layer in model.layers:
                if isinstance(layer, torch.nn.Linear):
                    current_x = layer(current_x)
                elif isinstance(layer, torch.nn.ReLU):
                    # Record which neurons are active (>0)
                    active = (current_x > 0).float()
                    pattern.append(active)
                    current_x = torch.relu(current_x)
        
        # Flatten and convert to tuple for hashing
        return tuple(torch.cat(pattern, dim=-1).flatten().tolist())
    
    # Create a grid of sample points
    x_vals = np.linspace(extent[0], extent[1], grid_resolution)
    y_vals = np.linspace(extent[2], extent[3], grid_resolution)
    
    # Dictionary to store points by their activation pattern
    pattern_to_points = {}
    
    print(f"Sampling {grid_resolution}x{grid_resolution} points to find activation patterns...")
    
    # Sample points and group by activation pattern
    for i, x in enumerate(x_vals):
        if i % (grid_resolution // 10) == 0:
            print(f"Progress: {i/grid_resolution*100:.1f}%")
            
        for y in y_vals:
            point = torch.tensor([[x, y]], dtype=torch.float32)
            pattern = get_relu_pattern(model, point)
            
            if pattern not in pattern_to_points:
                pattern_to_points[pattern] = []
            pattern_to_points[pattern].append([x, y])
    
    print(f"Found {len(pattern_to_points)} distinct activation patterns")
    
    # Convert regions to convex hulls and find corner points
    linear_regions = []
    
    for pattern, points in pattern_to_points.items():
        if len(points) < min_samples_per_region:
            continue
            
        points_array = np.array(points)
        
        try:
            # Find convex hull of points in this region
            hull = ConvexHull(points_array)
            corners = points_array[hull.vertices]
            linear_regions.append(corners)
            
        except Exception as e:
            warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
            continue
    
    print(f"Successfully extracted {len(linear_regions)} linear regions")
    
    # Refine boundaries by finding exact hyperplane intersections
    refined_regions = []
    
    for region_corners in linear_regions:
        # For small regions or those touching boundaries, use the sampled corners
        # For larger regions, we could implement exact hyperplane intersection finding
        refined_regions.append(region_corners)
    
    return refined_regions


def visualize_regions(regions, extent=[-1, 1, -1, 1], figsize=(6, 6)):
    """
    Helper function to visualize the found regions (requires matplotlib)
    """
    try:
        import matplotlib.pyplot as plt
        from matplotlib.patches import Polygon
        import matplotlib.colors as mcolors
        
        fig, ax = plt.subplots(1, 1, figsize=figsize)
        
        # Generate colors for each region
        colors = list(mcolors.TABLEAU_COLORS.values())
        
        for i, corners in enumerate(regions):
            color = colors[i % len(colors)]
            
            # Create polygon for this region
            polygon = Polygon(corners, alpha=0.3, facecolor=color, edgecolor='black', linewidth=0.5)
            ax.add_patch(polygon)
            
            # Mark corners
            # ax.scatter(corners[:, 0], corners[:, 1], c='red', s=10, zorder=5, alpha=0.5)
        
        ax.set_xlim(extent[0], extent[1])
        ax.set_ylim(extent[2], extent[3])
        ax.set_xlabel('x')
        ax.set_ylabel('y')
        ax.set_title(f'Linear Regions of ReLU Network ({len(regions)} regions)')
        ax.grid(True, alpha=0.3)
        ax.set_aspect('equal')
        
        plt.tight_layout()
        plt.show()
        
    except ImportError:
        print("matplotlib not available for visualization")

# %%
map=cv2.imread('Baarle-Nassau_-_Baarle-Hertog-en no legend.png')[:,:,(2,1,0)]

belgium_color=np.array([251,234,81])
netherlands_color=np.array([255, 255, 228])

netherlands_region=((map-netherlands_color)**2).sum(-1)<50
belgium_region=((map-belgium_color)**2).sum(-1)<10000

num_points_to_sample=10000 #10000

b_coords=np.array(np.where(belgium_region)).T.astype('float')
n_coords=np.array(np.where(netherlands_region)).T.astype('float')

#flip and normalize
belgium_coords_all=np.zeros_like(b_coords)
netherlands_coords_all=np.zeros_like(n_coords)

belgium_coords_all[:,0]=b_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
belgium_coords_all[:,1]=(960-b_coords[:,0])/(960/2)-1
netherlands_coords_all[:,0]=n_coords[:,1]/(960/2)-1 #Scale to -1 to 1 for now
netherlands_coords_all[:,1]=(960-n_coords[:,0])/(960/2)-1

## Hmm to balance to classes or do more area proportional? Not sure yet. 
# belgium_coords=belgium_coords_all[np.random.choice(len(belgium_coords_all), num_points_to_sample), :]
# netherlands_coords=netherlands_coords_all[np.random.choice(len(netherlands_coords_all), num_points_to_sample), :]

X=np.vstack((netherlands_coords_all, belgium_coords_all))
y=np.concatenate((np.zeros(len(netherlands_coords_all)), np.ones(len(belgium_coords_all)))).astype('int')

X_tensor = torch.FloatTensor(X)
y_tensor = torch.tensor(y)

# %%
map.shape
# Out:
# (960, 960, 3)

# %%
def viz_descision_boundary(model, res=256):
    plt.clf()
    fig=plt.figure(0,(6,6))
    ax=fig.add_subplot(111)
    
    probe=np.zeros((res,res,2))
    for j, xx in enumerate(np.linspace(-1, 1, res)):
        for k, yy in enumerate(np.linspace(-1, 1, res)):
            probe[j, k]=[yy,xx]
    probe=probe.reshape(res**2, -1)
    with torch.no_grad():
        probe_logits=model(torch.tensor(probe).float())
        probe_logits=probe_logits.detach().numpy().reshape(res,res,2)
        probe_softmax = torch.nn.Softmax(dim=1)(torch.tensor(probe_logits.reshape(-1, 2)))
    
    ax.imshow(map.mean(2), cmap='gray')
    ax.imshow(np.flipud(np.argmax(probe_logits,2)), 
               extent=[0, 960, 960, 0],  # This maps to image coordinates
               alpha=0.7,
               cmap='viridis')

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import os
from PIL import Image

def viz_and_save_heatmaps(model, save_dir="/Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/heatmaps", model_name="model", rez=960):
    """
    Generate and save heatmaps for a PyTorch model's output regions.
    
    Args:
        model: PyTorch model that takes 2D input and outputs 2 channels
        save_dir: Directory to save the heatmap images
        model_name: Base name for the saved files
        rez: Resolution for the heatmap generation
    """
    
    # Create save directory if it doesn't exist
    os.makedirs(save_dir, exist_ok=True)
    
    # Create probe grid at higher resolution
    probe = np.zeros((rez, rez, 2))
    for j, xx in enumerate(np.linspace(-1, 1, rez)):
        for k, yy in enumerate(np.linspace(-1, 1, rez)):
            probe[j, k] = [yy, xx]
    
    probe = probe.reshape(rez**2, -1)
    
    # Get model predictions
    with torch.no_grad():
        probe_logits = model(torch.tensor(probe).float())
        probe_logits = probe_logits.detach().numpy().reshape(rez, rez, 2)
    
    # Get argmax predictions for each pixel
    predictions = np.argmax(probe_logits, axis=2)
    
    # Define colors
    YELLOW = '#ffd35a'
    BLUE = '#65c8d0'
    
    # Create and save heatmaps for each channel
    colors = [BLUE, YELLOW]
    
    for channel in range(2):
        # Create binary mask for this channel
        channel_mask = (predictions == channel).astype(float)
        
        # Create RGBA image
        fig, ax = plt.subplots(figsize=(10, 10))
        ax.set_xlim(0, rez)
        ax.set_ylim(0, rez)
        ax.axis('off')
        
        # Create custom colormap: transparent where mask is 0, solid color where mask is 1
        color_rgb = [int(colors[channel][1:3], 16)/255, 
                     int(colors[channel][3:5], 16)/255, 
                     int(colors[channel][5:7], 16)/255]
        
        # Create binary colormap
        cmap_colors = [(0, 0, 0, 0),  # Transparent for value 0
                       (color_rgb[0], color_rgb[1], color_rgb[2], 1)]  # Solid color for value 1
        cmap = ListedColormap(cmap_colors)
        
        # Plot the binary mask (flip vertically to match image coordinates)
        im = ax.imshow(np.flipud(channel_mask), 
                      extent=[0, rez, 0, rez],
                      cmap=cmap,
                      vmin=0, vmax=1)
        
        # Save as PNG with transparency
        filename = f"{model_name}_{channel}.png"
        filepath = os.path.join(save_dir, filename)
        
        plt.savefig(filepath, 
                   bbox_inches='tight', 
                   pad_inches=0, 
                   transparent=True, 
                   dpi=100)
        
        plt.close()
        
        print(f"Saved {filename} to {save_dir}")
    
    print(f"Heatmaps saved as {model_name}_0.png and {model_name}_1.png")

# %%
X.shape, y.shape, X_tensor.shape, y_tensor.shape
# Out:
# ((855665, 2), (855665,), torch.Size([855665, 2]), torch.Size([855665]))

# %%
class BaarleNet(nn.Module):
    def __init__(self, hidden_layers=[64]):
        super(BaarleNet, self).__init__()
        layers = [nn.Linear(2, hidden_layers[0]), nn.ReLU()]
        for i in range(len(hidden_layers)-1):
            layers.append(nn.Linear(hidden_layers[i], hidden_layers[i+1]))
            layers.append(nn.ReLU())
        layers.append(nn.Linear(hidden_layers[-1], 2))
        self.layers=layers
        self.model = nn.Sequential(*layers)
    
    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## Single Layer

# %% [markdown]
# ## Shallow [2]

# %%
model_path='../models/2_1.pth'
model = BaarleNet([2])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.7268977929446687

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
visualize_regions(regions)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 4 distinct activation patterns
# Successfully extracted 4 linear regions

# %% [markdown]
# ## Shallow [3]

# %%
model_path='../models/3_1.pth'
model = BaarleNet([3])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.8173490793710155

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
visualize_regions(regions)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 5 distinct activation patterns
# Successfully extracted 5 linear regions

# %% [markdown]
# ## Shallow [4]

# %% [markdown]
# ## Shallow [8]

# %% [markdown]
# ## Shallow [16]

# %% [markdown]
# ## Shallow [32]

# %% [markdown]
# ## Shallow [64]

# %%
model=torch.load('../models/one_layer_64_nuerons_long.pt')

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.9358557379348226

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
visualize_regions(regions)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 630 distinct activation patterns
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate   -1
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587411234  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.055  Error-roundoff 8.6e-16  _one-merge 4.3e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.4e-15  _wide-facet 1e-14  _maxoutside 5.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 12 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate   -1
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587411234  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.086  Error-roundoff 8.6e-16  _one-merge 4.3e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.4e-15  _wide-facet 1e-14  _maxoutside 5.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.498
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587411234  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.2e-16  _one-merge 4.1e-15
#   _near-inside 2e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.3e-15  _wide-facet 9.8e-15  _maxoutside 4.9e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 11 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587411234  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.078  Error-roundoff 8.6e-16  _one-merge 4.3e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.4e-15  _wide-facet 1e-14  _maxoutside 5.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.73     1
# - p10(v2):   0.8     1
# - p0(v1):  0.73     1
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.7542        1
#
# facet p10 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p10 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.7255    0.8039  difference= 0.07843
#   1:         1         1  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587411234  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 8.3e-16  _one-merge 4.1e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.3e-15  _wide-facet 1e-14  _maxoutside 5e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.94  0.53
# - p5(v2):  0.97  0.53
# - p0(v1):  0.93  0.53
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.3e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.9451   0.5294
#
# facet p5 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.9294    0.9686  difference= 0.03922
#   1:    0.5294    0.5294  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.3e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# Successfully extracted 515 linear regions

# %% [markdown]
# ## Shallow [128]

# %% [markdown]
# ## Shallow [256]

# %% [markdown]
# ## Shallow [512]

# %%
model=torch.load('../models/one_layer_512_nuerons.pt')

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.9333442410289073

# %% [markdown]
# ## Shallow [1024]

# %%
model=torch.load('../models/one_layer_1024_nuerons_long.pt', weights_only=False)

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.9792769366516102

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 23249 distinct activation patterns
# Successfully extracted 2669 linear regions
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate   -1
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 8.6e-16  _one-merge 4.3e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.4e-15  _wide-facet 1e-14  _maxoutside 5.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.9608
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.2e-16  _one-merge 4.1e-15
#   _near-inside 2.1e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.3e-15  _wide-facet 9.9e-15  _maxoutside 4.9e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.9451
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.1e-16  _one-merge 4e-15
#   _near-inside 2e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.2e-15  _wide-facet 9.7e-15  _maxoutside 4.9e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.9294
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 6.8e-16  _one-merge 3.4e-15
#   _near-inside 1.7e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.7e-15  _wide-facet 8.2e-15  _maxoutside 4.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.9137
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.6e-16  _one-merge 3.8e-15
#   _near-inside 1.9e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 3e-15  _wide-facet 9.1e-15  _maxoutside 4.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.9059
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.8e-16  _one-merge 3.9e-15
#   _near-inside 1.9e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.1e-15  _wide-facet 9.3e-15  _maxoutside 4.7e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.898
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.7e-16  _one-merge 3.8e-15
#   _near-inside 1.9e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 3.1e-15  _wide-facet 9.2e-15  _maxoutside 4.6e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8902
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.6e-16  _one-merge 3.8e-15
#   _near-inside 1.9e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 3e-15  _wide-facet 9.1e-15  _maxoutside 4.6e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8824
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.055  Error-roundoff 7.3e-16  _one-merge 3.7e-15
#   _near-inside 1.8e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 2.9e-15  _wide-facet 8.8e-15  _maxoutside 4.4e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8745
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 7.5e-16  _one-merge 3.7e-15
#   _near-inside 1.9e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 3e-15  _wide-facet 9e-15  _maxoutside 4.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8588
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 6.3e-16  _one-merge 3.2e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.5e-15  _wide-facet 7.6e-15  _maxoutside 3.8e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.851
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 6.3e-16  _one-merge 3.1e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.5e-15  _wide-facet 7.5e-15  _maxoutside 3.8e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.851
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 6.1e-16  _one-merge 3.1e-15
#   _near-inside 1.5e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.4e-15  _wide-facet 7.3e-15  _maxoutside 3.7e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8431
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 6.5e-16  _one-merge 3.2e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.6e-15  _wide-facet 7.8e-15  _maxoutside 3.9e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8431
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.6e-16  _one-merge 4.3e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.4e-15  _wide-facet 1e-14  _maxoutside 5.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8353
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 6.8e-16  _one-merge 3.4e-15
#   _near-inside 1.7e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.7e-15  _wide-facet 8.2e-15  _maxoutside 4.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8275
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.1e-16  _one-merge 3.5e-15
#   _near-inside 1.8e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.8e-15  _wide-facet 8.5e-15  _maxoutside 4.3e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8196
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7e-16  _one-merge 3.5e-15
#   _near-inside 1.8e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.8e-15  _wide-facet 8.4e-15  _maxoutside 4.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8196
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 6.3e-16  _one-merge 3.1e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.5e-15  _wide-facet 7.5e-15  _maxoutside 3.8e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8118
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 7e-16  _one-merge 3.5e-15
#   _near-inside 1.7e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.8e-15  _wide-facet 8.3e-15  _maxoutside 4.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8118
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 6.2e-16  _one-merge 3.1e-15
#   _near-inside 1.5e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.5e-15  _wide-facet 7.4e-15  _maxoutside 3.7e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.8039
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.055  Error-roundoff 6.9e-16  _one-merge 3.4e-15
#   _near-inside 1.7e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.8e-15  _wide-facet 8.3e-15  _maxoutside 4.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.7961
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 5.8e-16  _one-merge 2.9e-15
#   _near-inside 1.5e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.3e-15  _wide-facet 7e-15  _maxoutside 3.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.7961
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.047  Error-roundoff 6e-16  _one-merge 3e-15
#   _near-inside 1.5e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.4e-15  _wide-facet 7.2e-15  _maxoutside 3.6e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.7882
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 5.8e-16  _one-merge 2.9e-15
#   _near-inside 1.4e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.3e-15  _wide-facet 6.9e-15  _maxoutside 3.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.7804
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 5.4e-16  _one-merge 2.7e-15
#   _near-inside 1.3e-14  Visible-distance 1.1e-15  U-max-coplanar 1.1e-15
#   Width-outside 2.1e-15  _wide-facet 6.4e-15  _maxoutside 3.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.7725
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 6.8e-16  _one-merge 3.4e-15
#   _near-inside 1.7e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.7e-15  _wide-facet 8.1e-15  _maxoutside 4.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 5.2e-16  _one-merge 2.6e-15
#   _near-inside 1.3e-14  Visible-distance 1e-15  U-max-coplanar 1e-15
#   Width-outside 2.1e-15  _wide-facet 6.3e-15  _maxoutside 3.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.76  0.02
# - p5(v2): -0.73  0.02
# - p0(v1): -0.76  0.02
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 5.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   -0.749  0.01961
#
# facet p5 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.7647  -2.225e-308  difference= 0.7647
#   1:   0.01961   0.01961  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 5.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.4e-16  _one-merge 4.2e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.3e-15  _wide-facet 1e-14  _maxoutside 5e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.65 -0.98
# - p4(v2): -0.63 -0.98
# - p0(v1): -0.66 -0.98
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.4e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.6497  -0.9765
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.6627  -2.225e-308  difference= 0.6627
#   1:   -0.9765  -2.225e-308  difference= 0.9765
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.4e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.6e-16  _one-merge 4.3e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.4e-15  _wide-facet 1e-14  _maxoutside 5.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.61    -1
# - p4(v2): -0.58    -1
# - p0(v1): -0.62    -1
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.6026       -1
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.6157  -2.225e-308  difference= 0.6157
#   1:        -1  -2.225e-308  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.063  Error-roundoff 5.2e-16  _one-merge 2.6e-15
#   _near-inside 1.3e-14  Visible-distance 1e-15  U-max-coplanar 1e-15
#   Width-outside 2.1e-15  _wide-facet 6.2e-15  _maxoutside 3.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.59 -0.54
# - p4(v2): -0.55 -0.56
# - p0(v1): -0.61 -0.53
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 5.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.5817  -0.5425
#
# facet p4 p0 distance= 5.6e-17
# facet p1 p0 distance=    0
# facet p1 p4 distance= -5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.6078  -2.225e-308  difference= 0.6078
#   1:   -0.5608  -2.225e-308  difference= 0.5608
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 5.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.498
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 4.3e-16  _one-merge 2.1e-15
#   _near-inside 1.1e-14  Visible-distance 8.5e-16  U-max-coplanar 8.5e-16
#   Width-outside 1.7e-15  _wide-facet 5.1e-15  _maxoutside 2.6e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.2e-16  _one-merge 4.1e-15
#   _near-inside 2.1e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.3e-15  _wide-facet 9.8e-15  _maxoutside 4.9e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.33    -1
# - p4(v2):  -0.3    -1
# - p0(v1): -0.33    -1
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.3203       -1
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.3333  -2.225e-308  difference= 0.3333
#   1:        -1  -2.225e-308  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8e-16  _one-merge 4e-15  _near-inside 2e-14
#   Visible-distance 1.6e-15  U-max-coplanar 1.6e-15  Width-outside 3.2e-15
#   _wide-facet 9.7e-15  _maxoutside 4.8e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.33 -0.98
# - p4(v2):  -0.3 -0.98
# - p0(v1): -0.33 -0.98
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.3203  -0.9765
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.3333  -2.225e-308  difference= 0.3333
#   1:   -0.9765  -2.225e-308  difference= 0.9765
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.7e-16  _one-merge 3.9e-15
#   _near-inside 1.9e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 3.1e-15  _wide-facet 9.3e-15  _maxoutside 4.6e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.25 -0.98
# - p4(v2): -0.23 -0.98
# - p0(v1): -0.26 -0.98
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 7.7e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.2497  -0.9765
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.2627  -2.225e-308  difference= 0.2627
#   1:   -0.9765  -2.225e-308  difference= 0.9765
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 7.7e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 4.1e-16  _one-merge 2.1e-15
#   _near-inside 1e-14  Visible-distance 8.3e-16  U-max-coplanar 8.3e-16
#   Width-outside 1.7e-15  _wide-facet 5e-15  _maxoutside 2.5e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.24 -0.47
# - p5(v2): -0.21 -0.44
# - p0(v1): -0.25 -0.48
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.1e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.2314  -0.4667
#
# facet p5 p0 distance=    0
# facet p1 p0 distance= 5.6e-17
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.2471  -2.225e-308  difference= 0.2471
#   1:   -0.4824  -2.225e-308  difference= 0.4824
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.1e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.063  Error-roundoff 6.3e-16  _one-merge 3.2e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.5e-15  _wide-facet 7.6e-15  _maxoutside 3.8e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.082  0.85
# - p4(v2): -0.035  0.87
# - p0(v1): -0.098  0.84
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.3e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.0719   0.8562
#
# facet p4 p0 distance=    0
# facet p1 p0 distance= 2.2e-16
# facet p1 p4 distance= 1.1e-16
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:  -0.09804  -2.225e-308  difference= 0.09804
#   1:    0.8431    0.8745  difference= 0.03137
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.3e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 6.6e-16  _one-merge 3.3e-15
#   _near-inside 1.7e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.7e-15  _wide-facet 8e-15  _maxoutside 4e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.035 -0.96
# - p5(v2): -0.0039 -0.96
# - p0(v1): -0.043 -0.96
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point -0.02745  -0.9608
#
# facet p5 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:  -0.04314  -2.225e-308  difference= 0.04314
#   1:   -0.9608  -2.225e-308  difference= 0.9608
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.063  Error-roundoff 3e-17  _one-merge 1.5e-16
#   _near-inside 7.6e-16  Visible-distance 6e-17  U-max-coplanar 6e-17
#   Width-outside 1.2e-16  _wide-facet 3.6e-16  _maxoutside 1.8e-16
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.012  0.02
# - p4(v2): 0.012 -0.027
# - p0(v1): -0.02 0.035
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3e-17.  The center point, facets and distances
# to the center point are as follows:
#
# center point -0.006536  0.00915
#
# facet p4 p0 distance= -2.9e-17
# facet p1 p0 distance= -1.2e-16
# facet p1 p4 distance= -3.8e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:  -0.01961   0.01176  difference= 0.03137
#   1:  -0.02745   0.03529  difference= 0.06275
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3e-17.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
# ...
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.6e-16  _one-merge 4.3e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.4e-15  _wide-facet 1e-14  _maxoutside 5.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):   0.8    -1
# - p4(v2):  0.83    -1
# - p0(v1):   0.8    -1
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.8092       -1
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.7961    0.8275  difference= 0.03137
#   1:        -1  -2.225e-308  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 8.5e-16  _one-merge 4.2e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.4e-15  _wide-facet 1e-14  _maxoutside 5.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):   0.8 -0.99
# - p5(v2):  0.84 -0.99
# - p0(v1):   0.8 -0.99
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.5e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.8118  -0.9922
#
# facet p5 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.7961    0.8353  difference= 0.03922
#   1:   -0.9922  -2.225e-308  difference= 0.9922
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.5e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.9e-16  _one-merge 3.9e-15
#   _near-inside 2e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.2e-15  _wide-facet 9.5e-15  _maxoutside 4.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):   0.8 -0.92
# - p4(v2):  0.83 -0.92
# - p0(v1):   0.8 -0.92
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 7.9e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.8092  -0.9216
#
# facet p4 p0 distance= 1.1e-16
# facet p1 p0 distance= -1.1e-16
# facet p1 p4 distance= -1.1e-16
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.7961    0.8275  difference= 0.03137
#   1:   -0.9216  -2.225e-308  difference= 0.9216
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 7.9e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.8e-16  _one-merge 3.9e-15
#   _near-inside 2e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.1e-15  _wide-facet 9.4e-15  _maxoutside 4.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):   0.8 -0.91
# - p4(v2):  0.83 -0.91
# - p0(v1):   0.8 -0.91
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 7.8e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.8092  -0.9137
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.7961    0.8275  difference= 0.03137
#   1:   -0.9137  -2.225e-308  difference= 0.9137
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 7.8e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.9e-16  _one-merge 3.9e-15
#   _near-inside 2e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.2e-15  _wide-facet 9.5e-15  _maxoutside 4.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.84 -0.92
# - p4(v2):  0.87 -0.92
# - p0(v1):  0.84 -0.92
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 7.9e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.8484  -0.9216
#
# facet p4 p0 distance= 1.1e-16
# facet p1 p0 distance= -1.1e-16
# facet p1 p4 distance= -1.1e-16
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.8353    0.8667  difference= 0.03137
#   1:   -0.9216  -2.225e-308  difference= 0.9216
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 7.9e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.9216
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 7.9e-16  _one-merge 3.9e-15
#   _near-inside 2e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.2e-15  _wide-facet 9.5e-15  _maxoutside 4.7e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 343956167  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 8.2e-16  _one-merge 4.1e-15
#   _near-inside 2.1e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.3e-15  _wide-facet 9.8e-15  _maxoutside 4.9e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p2(v3):  0.97 -0.34
# - p4(v2):  0.98 -0.33
# - p0(v1):  0.95 -0.36
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.9686  -0.3412
#
# facet p4 p0 distance= 5.6e-17
# facet p2 p0 distance= 5.6e-17
# facet p2 p4 distance= 5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.9529    0.9843  difference= 0.03137
#   1:   -0.3569  -2.225e-308  difference= 0.3569
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")

# %%
visualize_regions(regions)

# %%
torch.save(model.state_dict(), '../models/one_layer_1024_nuerons_long.pth')

# %% [markdown]
# ## Shallow [10k]
# - Super ram hungry, let's run on linux - do need to know if these get all the buildings...
# - Eh looks like i gotta batch it.

# %%
X_tensor.shape, y_tensor.shape
# Out:
# (torch.Size([855665, 2]), torch.Size([855665]))

# %%
# model=torch.load('../models/one_layer_10k_neurons_long.pt', weights_only=False)

# outputs_batch = model(X_tensor)
# accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

# print(accuracy); viz_descision_boundary(model)

# %%
# Load model
model = torch.load('../models/one_layer_10k_neurons_long.pt', weights_only=False)
model.eval()  # Set to evaluation mode

# Batch processing parameters
batch_size = 1000  # Adjust based on your available RAM
total_samples = len(X_tensor)
correct_predictions = 0

# Process in batches
with torch.no_grad():  # Disable gradient computation to save memory
    for i in range(0, total_samples, batch_size):
        # Get batch
        end_idx = min(i + batch_size, total_samples)
        X_batch = X_tensor[i:end_idx]
        y_batch = y_tensor[i:end_idx]
        
        # Forward pass
        outputs_batch = model(X_batch)
        
        # Calculate predictions and accumulate correct count
        predictions = torch.argmax(outputs_batch, dim=1)
        correct_predictions += (predictions == y_batch).sum().item()

# Calculate final accuracy
accuracy = correct_predictions / total_samples
print(f"Accuracy: {accuracy}")

# Visualize decision boundary (this will still use the full model)
viz_descision_boundary(model)
# Out:
# Accuracy: 0.977096176657921

# %%
torch.save(model.state_dict(), '../models/one_layer_10k_neurons_long.pth')

# %% [markdown]
# ## Shallow [100k]

# %%
# model=torch.load('../models/one_layer_100k_neurons_long.pt', weights_only=False)

# Load model
model = torch.load('../models/one_layer_100k_neurons_long.pt', weights_only=False)
model.eval()  # Set to evaluation mode
model.to('cpu')

# Batch processing parameters
batch_size = 1000  # Adjust based on your available RAM
total_samples = len(X_tensor)
correct_predictions = 0

# Process in batches
with torch.no_grad():  # Disable gradient computation to save memory
    for i in range(0, total_samples, batch_size):
        # Get batch
        end_idx = min(i + batch_size, total_samples)
        X_batch = X_tensor[i:end_idx]
        y_batch = y_tensor[i:end_idx]
        
        # Forward pass
        outputs_batch = model(X_batch)
        
        # Calculate predictions and accumulate correct count
        predictions = torch.argmax(outputs_batch, dim=1)
        correct_predictions += (predictions == y_batch).sum().item()

# Calculate final accuracy
accuracy = correct_predictions / total_samples
print(f"Accuracy: {accuracy}")

# Visualize decision boundary (this will still use the full model)
viz_descision_boundary(model)
# Out:
# Accuracy: 0.9808266085442316

# %%
torch.save(model.state_dict(), '../models/one_layer_100k_neurons_long.pth')

# %% [markdown]
# ## [2,2]

# %%
model_path='../models/2_2_1.pth'
model = BaarleNet([2,2])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.8239673236605447

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 11 distinct activation patterns
# Successfully extracted 11 linear regions

# %%
visualize_regions(regions)

# %% [markdown]
# ## [3,3]

# %%
model_path='../models/3_3_1.pth'
model = BaarleNet([3,3])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.8430659194895198

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
visualize_regions(regions)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 20 distinct activation patterns
# Successfully extracted 20 linear regions

# %% [markdown]
# ## [8, 8]

# %%
model_path='../models/8_8_1.pth'
model = BaarleNet([8,8])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.9275873151291686

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
visualize_regions(regions)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 100 distinct activation patterns
# Successfully extracted 95 linear regions

# %%
viz_and_save_heatmaps(model, model_name='8_8')
# Out:
# Saved 8_8_0.png to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/heatmaps
# Saved 8_8_1.png to /Users/stephen/Stephencwelch Dropbox/welch_labs/backprop_3/hackin/heatmaps
# Heatmaps saved as 8_8_0.png and 8_8_1.png

# %% [markdown]
# ## [16, 16]

# %%
model_path='../models/16_16_1.pth'
model = BaarleNet([16,16])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.9421642815821613

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
visualize_regions(regions)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 237 distinct activation patterns
# Successfully extracted 207 linear regions
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587579304  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.039  Error-roundoff 6.8e-16  _one-merge 3.4e-15
#   _near-inside 1.7e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.7e-15  _wide-facet 8.1e-15  _maxoutside 4.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.78 -0.49
# - p5(v2): -0.75 -0.49
# - p0(v1): -0.79 -0.49
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.8e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.7725  -0.4902
#
# facet p5 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.7882  -2.225e-308  difference= 0.7882
#   1:   -0.4902  -2.225e-308  difference= 0.4902
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.8e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")

# %% [markdown]
# ## [2,2,2]

# %%
model_path='../models/2_2_2_1.pth'
model = BaarleNet([2,2,2])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.8390386424593737

# %% [markdown]
# ## [16, 16, 16]

# %%
model_path='../models/16_16_16_1.pth'
model = BaarleNet([16,16,16])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.9488514780901404

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=256)
visualize_regions(regions)
# Out:
# Sampling 256x256 points to find activation patterns...
# Progress: 0.0%
# Progress: 9.8%
# Progress: 19.5%
# Progress: 29.3%
# Progress: 39.1%
# Progress: 48.8%
# Progress: 58.6%
# Progress: 68.4%
# Progress: 78.1%
# Progress: 87.9%
# Progress: 97.7%
# Found 514 distinct activation patterns
# Successfully extracted 419 linear regions
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587646532  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.047  Error-roundoff 2.8e-16  _one-merge 1.4e-15
#   _near-inside 7e-15  Visible-distance 5.6e-16  U-max-coplanar 5.6e-16
#   Width-outside 1.1e-15  _wide-facet 3.3e-15  _maxoutside 1.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p4(v3): -0.22 -0.29
# - p6(v2): -0.21 -0.28
# - p0(v1): -0.25 -0.33
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.8e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.2288  -0.2993
#
# facet p6 p0 distance= -2.8e-17
# facet p4 p0 distance= -5.6e-17
# facet p4 p6 distance= -8.3e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.2549  -2.225e-308  difference= 0.2549
#   1:   -0.3255  -2.225e-308  difference= 0.3255
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.8e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.2392
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587646532  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.055  Error-roundoff 2e-16  _one-merge 1e-15
#   _near-inside 5.1e-15  Visible-distance 4.1e-16  U-max-coplanar 4.1e-16
#   Width-outside 8.2e-16  _wide-facet 2.5e-15  _maxoutside 1.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587646532  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.055  Error-roundoff 1.6e-16  _one-merge 7.9e-16
#   _near-inside 3.9e-15  Visible-distance 3.1e-16  U-max-coplanar 3.1e-16
#   Width-outside 6.3e-16  _wide-facet 1.9e-15  _maxoutside 9.4e-16
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p4(v3): 0.051 -0.15
# - p7(v2): 0.075 -0.13
# - p0(v1):  0.02 -0.18
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 1.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  0.04837  -0.1556
#
# facet p7 p0 distance= -1.4e-17
# facet p4 p0 distance= -4.2e-17
# facet p4 p7 distance= -4.2e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   0.01961   0.07451  difference= 0.0549
#   1:   -0.1843  -2.225e-308  difference= 0.1843
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 1.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.1608
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587646532  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.047  Error-roundoff 1.2e-16  _one-merge 6.2e-16
#   _near-inside 3.1e-15  Visible-distance 2.5e-16  U-max-coplanar 2.5e-16
#   Width-outside 4.9e-16  _wide-facet 1.5e-15  _maxoutside 7.4e-16
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587646532  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 4.3e-16  _one-merge 2.2e-15
#   _near-inside 1.1e-14  Visible-distance 8.7e-16  U-max-coplanar 8.7e-16
#   Width-outside 1.7e-15  _wide-facet 5.2e-15  _maxoutside 2.6e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.48  0.36
# - p4(v2):  0.51  0.36
# - p0(v1):  0.47  0.36
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.3e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.4876   0.3569
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.4745    0.5059  difference= 0.03137
#   1:    0.3569    0.3569  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.3e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_13792/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 587646532  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.031  Error-roundoff 5.2e-16  _one-merge 2.6e-15
#   _near-inside 1.3e-14  Visible-distance 1e-15  U-max-coplanar 1e-15
#   Width-outside 2.1e-15  _wide-facet 6.2e-15  _maxoutside 3.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.58  0.37
# - p4(v2):  0.61  0.37
# - p0(v1):  0.58  0.37
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 5.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.5895   0.3725
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.5765    0.6078  difference= 0.03137
#   1:    0.3725    0.3725  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 5.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")

# %% [markdown]
# Cools.

# %% [markdown]
# ## 32 32 32

# %%
model_path='../models/32_32_32_1.pth'
model = BaarleNet([32, 32, 32])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.9880560733464615

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=1024);
# visualize_regions(regions)
# Out:
# Sampling 1024x1024 points to find activation patterns...
# Progress: 0.0%
# Progress: 10.0%
# Progress: 19.9%
# Progress: 29.9%
# Progress: 39.8%
# Progress: 49.8%
# Progress: 59.8%
# Progress: 69.7%
# Progress: 79.7%
# Progress: 89.6%
# Progress: 99.6%
# Found 4031 distinct activation patterns
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.016  Error-roundoff 7.9e-16  _one-merge 4e-15
#   _near-inside 2e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.2e-15  _wide-facet 9.5e-15  _maxoutside 4.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  -0.7  0.92
# - p4(v2):  -0.7  0.91
# - p0(v1): -0.71  0.92
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 7.9e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.7035   0.9172
#
# facet p4 p0 distance= 5.6e-17
# facet p1 p0 distance= -5.6e-17
# facet p1 p4 distance= -5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.7067  -2.225e-308  difference= 0.7067
#   1:    0.9081    0.9238  difference= 0.01564
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 7.9e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.5288
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 4e-16  _one-merge 2e-15  _near-inside 1e-14
#   Visible-distance 8e-16  U-max-coplanar 8e-16  Width-outside 1.6e-15
#   _wide-facet 4.8e-15  _maxoutside 2.4e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.5269
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 4.2e-16  _one-merge 2.1e-15
#   _near-inside 1e-14  Visible-distance 8.3e-16  U-max-coplanar 8.3e-16
#   Width-outside 1.7e-15  _wide-facet 5e-15  _maxoutside 2.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 11 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.5269
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.02  Error-roundoff 3.7e-16  _one-merge 1.9e-15
#   _near-inside 9.3e-15  Visible-distance 7.5e-16  U-max-coplanar 7.5e-16
#   Width-outside 1.5e-15  _wide-facet 4.5e-15  _maxoutside 2.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.027  Error-roundoff 3.3e-16  _one-merge 1.7e-15
#   _near-inside 8.3e-15  Visible-distance 6.6e-16  U-max-coplanar 6.6e-16
#   Width-outside 1.3e-15  _wide-facet 4e-15  _maxoutside 2e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.38  0.18
# - p7(v2): -0.36  0.19
# - p0(v1): -0.39  0.18
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.3e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.3776   0.1821
#
# facet p7 p0 distance= -5.6e-17
# facet p1 p0 distance=    0
# facet p1 p7 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.3881  -2.225e-308  difference= 0.3881
#   1:    0.1769    0.1906  difference= 0.01369
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.3e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.349
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 4.7e-16  _one-merge 2.4e-15
#   _near-inside 1.2e-14  Visible-distance 9.5e-16  U-max-coplanar 9.5e-16
#   Width-outside 1.9e-15  _wide-facet 5.7e-15  _maxoutside 2.8e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.3431
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 2.4e-16  _one-merge 1.2e-15
#   _near-inside 6e-15  Visible-distance 4.8e-16  U-max-coplanar 4.8e-16
#   Width-outside 9.6e-16  _wide-facet 2.9e-15  _maxoutside 1.4e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.3001
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.014  Error-roundoff 2.6e-16  _one-merge 1.3e-15
#   _near-inside 6.4e-15  Visible-distance 5.1e-16  U-max-coplanar 5.1e-16
#   Width-outside 1e-15  _wide-facet 3.1e-15  _maxoutside 1.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.2786
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 7e-16  _one-merge 3.5e-15
#   _near-inside 1.7e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.8e-15  _wide-facet 8.4e-15  _maxoutside 4.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.2766
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.014  Error-roundoff 7.3e-16  _one-merge 3.6e-15
#   _near-inside 1.8e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 2.9e-15  _wide-facet 8.7e-15  _maxoutside 4.4e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 9 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.2766
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.016  Error-roundoff 7.1e-16  _one-merge 3.6e-15
#   _near-inside 1.8e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.8e-15  _wide-facet 8.5e-15  _maxoutside 4.3e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 22 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.2747
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.041  Error-roundoff 7.6e-16  _one-merge 3.8e-15
#   _near-inside 1.9e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 3.1e-15  _wide-facet 9.2e-15  _maxoutside 4.6e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.2727
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 7.9e-16  _one-merge 4e-15
#   _near-inside 2e-14  Visible-distance 1.6e-15  U-max-coplanar 1.6e-15
#   Width-outside 3.2e-15  _wide-facet 9.5e-15  _maxoutside 4.8e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339519119  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 6.6e-16  _one-merge 3.3e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.6e-15  _wide-facet 7.9e-15  _maxoutside 3.9e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.13 -0.89
# - p4(v2): -0.13 -0.89
# - p0(v1): -0.13 -0.89
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.1307  -0.8905
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.1339  -2.225e-308  difference= 0.1339
#   1:   -0.8905  -2.225e-308  difference= 0.8905
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.012  Error-roundoff 5.3e-16  _one-merge 2.7e-15
#   _near-inside 1.3e-14  Visible-distance 1.1e-15  U-max-coplanar 1.1e-15
#   Width-outside 2.1e-15  _wide-facet 6.4e-15  _maxoutside 3.2e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.017 -0.78
# - p6(v2): -0.0068 -0.78
# - p0(v1): -0.019 -0.78
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 5.3e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point -0.01401  -0.7791
#
# facet p6 p0 distance= 1.1e-16
# facet p1 p0 distance= -1.1e-16
# facet p1 p6 distance= -1.1e-16
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:  -0.01857  -2.225e-308  difference= 0.01857
#   1:   -0.7791  -2.225e-308  difference= 0.7791
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 5.3e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 5.4e-16  _one-merge 2.7e-15
#   _near-inside 1.3e-14  Visible-distance 1.1e-15  U-max-coplanar 1.1e-15
#   Width-outside 2.1e-15  _wide-facet 6.4e-15  _maxoutside 3.2e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.22 -0.64
# - p5(v2):  0.23 -0.63
# - p0(v1):  0.22 -0.64
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 5.4e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.2258  -0.6403
#
# facet p5 p0 distance= 5.6e-17
# facet p1 p0 distance= -5.6e-17
# facet p1 p5 distance= -5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.2219    0.2317  difference= 0.009775
#   1:   -0.6442  -2.225e-308  difference= 0.6442
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 5.4e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 8 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.2239
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.014  Error-roundoff 7.4e-16  _one-merge 3.7e-15
#   _near-inside 1.9e-14  Visible-distance 1.5e-15  U-max-coplanar 1.5e-15
#   Width-outside 3e-15  _wide-facet 8.9e-15  _maxoutside 4.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.3001
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 6.2e-16  _one-merge 3.1e-15
#   _near-inside 1.6e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.5e-15  _wide-facet 7.5e-15  _maxoutside 3.7e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.016  Error-roundoff 3.9e-16  _one-merge 1.9e-15
#   _near-inside 9.6e-15  Visible-distance 7.7e-16  U-max-coplanar 7.7e-16
#   Width-outside 1.5e-15  _wide-facet 4.6e-15  _maxoutside 2.3e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.44 -0.41
# - p4(v2):  0.45  -0.4
# - p0(v1):  0.44 -0.42
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.9e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.4461  -0.4109
#
# facet p4 p0 distance= -2.8e-17
# facet p1 p0 distance= 2.8e-17
# facet p1 p4 distance= 2.8e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.4428    0.4506  difference= 0.00782
#   1:   -0.4174  -2.225e-308  difference= 0.4174
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.9e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.016  Error-roundoff 4.1e-16  _one-merge 2.1e-15
#   _near-inside 1e-14  Visible-distance 8.3e-16  U-max-coplanar 8.3e-16
#   Width-outside 1.7e-15  _wide-facet 5e-15  _maxoutside 2.5e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.48  -0.3
# - p4(v2):  0.48 -0.29
# - p0(v1):  0.48 -0.31
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.1e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.4793  -0.2994
#
# facet p4 p0 distance= -5.6e-17
# facet p1 p0 distance= 5.6e-17
# facet p1 p4 distance= 5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.4761    0.4839  difference= 0.00782
#   1:    -0.306  -2.225e-308  difference= 0.306
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.1e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 9 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.016  Error-roundoff 4.8e-16  _one-merge 2.4e-15
#   _near-inside 1.2e-14  Visible-distance 9.5e-16  U-max-coplanar 9.5e-16
#   Width-outside 1.9e-15  _wide-facet 5.7e-15  _maxoutside 2.9e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.54  0.49
# - p8(v2):  0.56  0.49
# - p0(v1):  0.54  0.49
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.8e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.5464   0.4917
#
# facet p8 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p8 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.5406    0.5562  difference= 0.01564
#   1:    0.4917    0.4917  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.8e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.7146
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 5.8e-16  _one-merge 2.9e-15
#   _near-inside 1.5e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.3e-15  _wide-facet 7e-15  _maxoutside 3.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 339535926  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.012  Error-roundoff 6.3e-16  _one-merge 3.2e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.5e-15  _wide-facet 7.6e-15  _maxoutside 3.8e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.73  0.67
# - p6(v2):  0.74  0.66
# - p0(v1):  0.72  0.67
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.3e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.7289   0.6689
#
# facet p6 p0 distance= -5.6e-17
# facet p1 p0 distance= 1.7e-16
# facet p1 p6 distance= -5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.7243    0.7361  difference= 0.01173
#   1:    0.6618    0.6735  difference= 0.01173
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.3e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# Successfully extracted 3438 linear regions

# %%
visualize_regions(regions)

# %% [markdown]
# ## 32 32 32 32

# %%
model_path='../models/32_32_32_32_1.pth'
model = BaarleNet([32, 32, 32, 32])
model.load_state_dict(torch.load(model_path))

outputs_batch = model(X_tensor)
accuracy=(torch.argmax(outputs_batch, dim=1)==y_tensor).sum().item()/len(y)

print(accuracy); viz_descision_boundary(model)
# Out:
# 0.9976544558910321

# %%
regions = find_linear_regions_empirical(model, extent=[-1, 1, -1, 1], grid_resolution=1024);
# Out:
# Sampling 1024x1024 points to find activation patterns...
# Progress: 0.0%
# Progress: 10.0%
# Progress: 19.9%
# Progress: 29.9%
# Progress: 39.8%
# Progress: 49.8%
# Progress: 59.8%
# Progress: 69.7%
# Progress: 79.7%
# Progress: 89.6%
# Progress: 99.6%
# Found 9895 distinct activation patterns
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.012  Error-roundoff 7.2e-16  _one-merge 3.6e-15
#   _near-inside 1.8e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.9e-15  _wide-facet 8.7e-15  _maxoutside 4.3e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.92 -0.23
# - p6(v2): -0.91 -0.22
# - p0(v1): -0.92 -0.24
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 7.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.9172   -0.231
#
# facet p6 p0 distance= -5.6e-17
# facet p1 p0 distance= -2.8e-17
# facet p1 p6 distance= -5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.9218  -2.225e-308  difference= 0.9218
#   1:   -0.2356  -2.225e-308  difference= 0.2356
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 7.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 15 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.027  Error-roundoff 7.1e-16  _one-merge 3.6e-15
#   _near-inside 1.8e-14  Visible-distance 1.4e-15  U-max-coplanar 1.4e-15
#   Width-outside 2.8e-15  _wide-facet 8.5e-15  _maxoutside 4.3e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.91 -0.22
# - p14(v2): -0.88 -0.19
# - p0(v1): -0.91 -0.22
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 7.1e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.9022  -0.2102
#
# facet p14 p0 distance=    0
# facet p1 p0 distance= 8.3e-17
# facet p1 p14 distance= 1.1e-16
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    -0.912  -2.225e-308  difference= 0.912
#   1:   -0.2199  -2.225e-308  difference= 0.2199
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 7.1e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 6.6e-16  _one-merge 3.3e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.6e-15  _wide-facet 7.9e-15  _maxoutside 4e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.87 -0.17
# - p5(v2): -0.86 -0.17
# - p0(v1): -0.87 -0.17
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.8631  -0.1711
#
# facet p5 p0 distance= 4.2e-17
# facet p1 p0 distance= 4.2e-17
# facet p1 p5 distance= 4.2e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.8671  -2.225e-308  difference= 0.8671
#   1:    -0.175  -2.225e-308  difference= 0.175
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 6.2e-16  _one-merge 3.1e-15
#   _near-inside 1.5e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.5e-15  _wide-facet 7.4e-15  _maxoutside 3.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.83 -0.13
# - p4(v2): -0.82 -0.13
# - p0(v1): -0.83 -0.13
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.8267  -0.1307
#
# facet p4 p0 distance= 1.4e-17
# facet p1 p0 distance=    0
# facet p1 p4 distance= -1.1e-16
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.8299  -2.225e-308  difference= 0.8299
#   1:   -0.1339  -2.225e-308  difference= 0.1339
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 6.4e-16  _one-merge 3.2e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.6e-15  _wide-facet 7.7e-15  _maxoutside 3.8e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.74 -0.36
# - p4(v2): -0.74 -0.36
# - p0(v1): -0.75 -0.36
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.4e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.7426  -0.3614
#
# facet p4 p0 distance= -5.6e-17
# facet p1 p0 distance= 1.1e-16
# facet p1 p4 distance= -5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.7458  -2.225e-308  difference= 0.7458
#   1:   -0.3646  -2.225e-308  difference= 0.3646
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.4e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.7419
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 5.9e-16  _one-merge 2.9e-15
#   _near-inside 1.5e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.3e-15  _wide-facet 7e-15  _maxoutside 3.5e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 9 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.016  Error-roundoff 6.2e-16  _one-merge 3.1e-15
#   _near-inside 1.6e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.5e-15  _wide-facet 7.4e-15  _maxoutside 3.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.72 -0.38
# - p8(v2): -0.71 -0.37
# - p0(v1): -0.72 -0.39
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.7185  -0.3803
#
# facet p8 p0 distance= -5.6e-17
# facet p1 p0 distance= 5.6e-17
# facet p1 p8 distance= 5.6e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.7243  -2.225e-308  difference= 0.7243
#   1:   -0.3861  -2.225e-308  difference= 0.3861
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.65
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 5.2e-16  _one-merge 2.6e-15
#   _near-inside 1.3e-14  Visible-distance 1e-15  U-max-coplanar 1e-15
#   Width-outside 2.1e-15  _wide-facet 6.2e-15  _maxoutside 3.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 10 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.6246
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.018  Error-roundoff 5.3e-16  _one-merge 2.7e-15
#   _near-inside 1.3e-14  Visible-distance 1.1e-15  U-max-coplanar 1.1e-15
#   Width-outside 2.1e-15  _wide-facet 6.4e-15  _maxoutside 3.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.6109
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 5.2e-16  _one-merge 2.6e-15
#   _near-inside 1.3e-14  Visible-distance 1e-15  U-max-coplanar 1e-15
#   Width-outside 2.1e-15  _wide-facet 6.3e-15  _maxoutside 3.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.5464
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 4.4e-16  _one-merge 2.2e-15
#   _near-inside 1.1e-14  Visible-distance 8.8e-16  U-max-coplanar 8.8e-16
#   Width-outside 1.8e-15  _wide-facet 5.3e-15  _maxoutside 2.6e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 16 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.5288
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.029  Error-roundoff 3.6e-16  _one-merge 1.8e-15
#   _near-inside 9.1e-15  Visible-distance 7.3e-16  U-max-coplanar 7.3e-16
#   Width-outside 1.5e-15  _wide-facet 4.4e-15  _maxoutside 2.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 23 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.5288
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.043  Error-roundoff 3.8e-16  _one-merge 1.9e-15
#   _near-inside 9.6e-15  Visible-distance 7.7e-16  U-max-coplanar 7.7e-16
#   Width-outside 1.5e-15  _wide-facet 4.6e-15  _maxoutside 2.3e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.4995
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 4.3e-16  _one-merge 2.1e-15
#   _near-inside 1.1e-14  Visible-distance 8.6e-16  U-max-coplanar 8.6e-16
#   Width-outside 1.7e-15  _wide-facet 5.1e-15  _maxoutside 2.6e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.012  Error-roundoff 4.1e-16  _one-merge 2.1e-15
#   _near-inside 1e-14  Visible-distance 8.3e-16  U-max-coplanar 8.3e-16
#   Width-outside 1.7e-15  _wide-facet 5e-15  _maxoutside 2.5e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.49  0.19
# - p6(v2): -0.48  0.19
# - p0(v1): -0.49  0.19
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.1e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.4891   0.1867
#
# facet p6 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p6 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.4936  -2.225e-308  difference= 0.4936
#   1:    0.1867    0.1867  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.1e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 12 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.022  Error-roundoff 4.1e-16  _one-merge 2e-15
#   _near-inside 1e-14  Visible-distance 8.1e-16  U-max-coplanar 8.1e-16
#   Width-outside 1.6e-15  _wide-facet 4.9e-15  _maxoutside 2.4e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.48  0.19
# - p11(v2): -0.46  0.19
# - p0(v1): -0.48  0.19
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.1e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.4721   0.1867
#
# facet p11 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p11 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:     -0.48  -2.225e-308  difference= 0.48
#   1:    0.1867    0.1867  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.1e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.012  Error-roundoff 3.8e-16  _one-merge 1.9e-15
#   _near-inside 9.6e-15  Visible-distance 7.7e-16  U-max-coplanar 7.7e-16
#   Width-outside 1.5e-15  _wide-facet 4.6e-15  _maxoutside 2.3e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.45  0.29
# - p6(v2): -0.44  0.29
# - p0(v1): -0.45  0.29
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.8e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.4441   0.2903
#
# facet p6 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p6 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.4487  -2.225e-308  difference= 0.4487
#   1:    0.2903    0.2903  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.8e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 9 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.4448
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.016  Error-roundoff 3.4e-16  _one-merge 1.7e-15
#   _near-inside 8.4e-15  Visible-distance 6.7e-16  U-max-coplanar 6.7e-16
#   Width-outside 1.3e-15  _wide-facet 4e-15  _maxoutside 2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 5.2e-16  _one-merge 2.6e-15
#   _near-inside 1.3e-14  Visible-distance 1e-15  U-max-coplanar 1e-15
#   Width-outside 2.1e-15  _wide-facet 6.3e-15  _maxoutside 3.1e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.43 -0.61
# - p4(v2): -0.43 -0.61
# - p0(v1): -0.44 -0.61
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 5.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.4337  -0.6083
#
# facet p4 p0 distance= -5.6e-17
# facet p1 p0 distance= 5.6e-17
# facet p1 p4 distance= 1.1e-16
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    -0.437  -2.225e-308  difference= 0.437
#   1:   -0.6129  -2.225e-308  difference= 0.6129
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 5.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 3.7e-16  _one-merge 1.8e-15
#   _near-inside 9.2e-15  Visible-distance 7.3e-16  U-max-coplanar 7.3e-16
#   Width-outside 1.5e-15  _wide-facet 4.4e-15  _maxoutside 2.2e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.43  0.26
# - p4(v2): -0.42  0.26
# - p0(v1): -0.43  0.26
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.7e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.4259    0.261
#
# facet p4 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.4291  -2.225e-308  difference= 0.4291
#   1:     0.261     0.261  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.7e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 7 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.012  Error-roundoff 3.6e-16  _one-merge 1.8e-15
#   _near-inside 9.1e-15  Visible-distance 7.2e-16  U-max-coplanar 7.2e-16
#   Width-outside 1.4e-15  _wide-facet 4.3e-15  _maxoutside 2.2e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.42  0.29
# - p6(v2): -0.41  0.29
# - p0(v1): -0.42  0.29
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.4187   0.2903
#
# facet p6 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p6 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.4233  -2.225e-308  difference= 0.4233
#   1:    0.2903    0.2903  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 12 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.022  Error-roundoff 3.1e-16  _one-merge 1.6e-15
#   _near-inside 7.8e-15  Visible-distance 6.2e-16  U-max-coplanar 6.2e-16
#   Width-outside 1.2e-15  _wide-facet 3.7e-15  _maxoutside 1.9e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.36  0.29
# - p11(v2): -0.34  0.29
# - p0(v1): -0.36  0.29
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.1e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.3568   0.2864
#
# facet p11 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p11 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.3646  -2.225e-308  difference= 0.3646
#   1:    0.2864    0.2864  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.1e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 9 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.016  Error-roundoff 8.3e-16  _one-merge 4.2e-15
#   _near-inside 2.1e-14  Visible-distance 1.7e-15  U-max-coplanar 1.7e-15
#   Width-outside 3.3e-15  _wide-facet 1e-14  _maxoutside 5e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.36    -1
# - p8(v2): -0.35    -1
# - p0(v1): -0.36    -1
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 8.3e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.3548       -1
#
# facet p8 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p8 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.3607  -2.225e-308  difference= 0.3607
#   1:        -1  -2.225e-308  difference=    1
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 8.3e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 11 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.02  Error-roundoff 2.9e-16  _one-merge 1.5e-15
#   _near-inside 7.3e-15  Visible-distance 5.8e-16  U-max-coplanar 5.8e-16
#   Width-outside 1.2e-15  _wide-facet 3.5e-15  _maxoutside 1.8e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.34  0.23
# - p10(v2): -0.32  0.23
# - p0(v1): -0.34  0.23
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.9e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   -0.334   0.2278
#
# facet p10 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p10 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.3412  -2.225e-308  difference= 0.3412
#   1:    0.2278    0.2278  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.9e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 2.9e-16  _one-merge 1.4e-15
#   _near-inside 7.1e-15  Visible-distance 5.7e-16  U-max-coplanar 5.7e-16
#   Width-outside 1.1e-15  _wide-facet 3.4e-15  _maxoutside 1.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3): -0.33  0.28
# - p5(v2): -0.32  0.28
# - p0(v1): -0.33  0.28
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.9e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point  -0.3294   0.2845
#
# facet p5 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:   -0.3333  -2.225e-308  difference= 0.3333
#   1:    0.2845    0.2845  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.9e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate -0.1652
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 4.9e-16  _one-merge 2.5e-15
#   _near-inside 1.2e-14  Visible-distance 9.8e-16  U-max-coplanar 9.8e-16
#   Width-outside 2e-15  _wide-facet 5.9e-15  _maxoutside 2.9e-15
#
# ...
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 2.5e-16  _one-merge 1.3e-15
#   _near-inside 6.3e-15  Visible-distance 5e-16  U-max-coplanar 5e-16
#   Width-outside 1e-15  _wide-facet 3e-15  _maxoutside 1.5e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.28 -0.27
# - p5(v2):  0.29 -0.26
# - p0(v1):  0.28 -0.27
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 2.5e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.2864  -0.2669
#
# facet p5 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.2825    0.2923  difference= 0.009775
#   1:   -0.2708  -2.225e-308  difference= 0.2708
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 2.5e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 6.2e-16  _one-merge 3.1e-15
#   _near-inside 1.6e-14  Visible-distance 1.2e-15  U-max-coplanar 1.2e-15
#   Width-outside 2.5e-15  _wide-facet 7.5e-15  _maxoutside 3.7e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.46  0.72
# - p4(v2):  0.46  0.73
# - p0(v1):  0.46  0.72
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 6.2e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.4598   0.7237
#
# facet p4 p0 distance=    0
# facet p1 p0 distance= 1.1e-16
# facet p1 p4 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.4565    0.4643  difference= 0.00782
#   1:    0.7204    0.7283  difference= 0.00782
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 6.2e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.4995
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 3.6e-16  _one-merge 1.8e-15
#   _near-inside 8.9e-15  Visible-distance 7.1e-16  U-max-coplanar 7.1e-16
#   Width-outside 1.4e-15  _wide-facet 4.3e-15  _maxoutside 2.1e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.5015
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 3.7e-16  _one-merge 1.8e-15
#   _near-inside 9.2e-15  Visible-distance 7.4e-16  U-max-coplanar 7.4e-16
#   Width-outside 1.5e-15  _wide-facet 4.4e-15  _maxoutside 2.2e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 3.6e-16  _one-merge 1.8e-15
#   _near-inside 9e-15  Visible-distance 7.2e-16  U-max-coplanar 7.2e-16
#   Width-outside 1.4e-15  _wide-facet 4.3e-15  _maxoutside 2.2e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.53 -0.0049
# - p4(v2):  0.53 0.00098
# - p0(v1):  0.52 -0.0068
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 3.6e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.5282 -0.003584
#
# facet p4 p0 distance= 1.6e-17
# facet p1 p0 distance= -7.2e-17
# facet p1 p4 distance= -7.1e-17
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.5249    0.5327  difference= 0.00782
#   1:  -0.006843  0.0009775  difference= 0.00782
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 3.6e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.5288
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 4.5e-16  _one-merge 2.2e-15
#   _near-inside 1.1e-14  Visible-distance 8.9e-16  U-max-coplanar 8.9e-16
#   Width-outside 1.8e-15  _wide-facet 5.4e-15  _maxoutside 2.7e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# Successfully extracted 7650 linear regions
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.6618
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 5.7e-16  _one-merge 2.8e-15
#   _near-inside 1.4e-14  Visible-distance 1.1e-15  U-max-coplanar 1.1e-15
#   Width-outside 2.3e-15  _wide-facet 6.8e-15  _maxoutside 3.4e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 6 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0098  Error-roundoff 4.8e-16  _one-merge 2.4e-15
#   _near-inside 1.2e-14  Visible-distance 9.7e-16  U-max-coplanar 9.7e-16
#   Width-outside 1.9e-15  _wide-facet 5.8e-15  _maxoutside 2.9e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.68  0.05
# - p5(v2):  0.69  0.05
# - p0(v1):  0.68  0.05
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 4.8e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.6813  0.04985
#
# facet p5 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p5 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.6774    0.6872  difference= 0.009775
#   1:   0.04985   0.04985  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 4.8e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 19 points: QH6154 Qhull precision error: Initial simplex is flat (facet 1 is coplanar with the interior point)
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.035  Error-roundoff 5.4e-16  _one-merge 2.7e-15
#   _near-inside 1.3e-14  Visible-distance 1.1e-15  U-max-coplanar 1.1e-15
#   Width-outside 2.2e-15  _wide-facet 6.5e-15  _maxoutside 3.2e-15
#
# The input to qhull appears to be less than 2 dimensional, or a
# computation has overflowed.
#
# Qhull could not construct a clearly convex simplex from points:
# - p1(v3):  0.74 0.048
# - p18(v2):  0.77 0.048
# - p0(v1):  0.74 0.048
#
# The center point is coplanar with a facet, or a vertex is coplanar
# with a neighboring facet.  The maximum round off error for
# computing distances is 5.4e-16.  The center point, facets and distances
# to the center point are as follows:
#
# center point   0.7485   0.0479
#
# facet p18 p0 distance=    0
# facet p1 p0 distance=    0
# facet p1 p18 distance=    0
#
# These points either have a maximum or minimum x-coordinate, or
# they maximize the determinant for k coordinates.  Trial points
# are first selected from points that maximize a coordinate.
#
# The min and max coordinates for each dimension are:
#   0:    0.7361    0.7713  difference= 0.03519
#   1:    0.0479    0.0479  difference=    0
#
# If the input should be full dimensional, you have several options that
# may determine an initial simplex:
#   - use 'QJ'  to joggle the input and make it full dimensional
#   - use 'QbB' to scale the points to the unit cube
#   - use 'QR0' to randomly rotate the input for different maximum points
#   - use 'Qs'  to search all points for the initial simplex
#   - use 'En'  to specify a maximum roundoff error less than 5.4e-16.
#   - trace execution with 'T3' to see the determinant for each point.
#
# If the input is lower dimensional:
#   - use 'QJ' to joggle the input and make it full dimensional
#   - use 'Qbk:0Bk:0' to delete coordinate k from the input.  You should
#     pick the coordinate with the least range.  The hull will have the
#     correct topology.
#   - determine the flat containing the points, rotate the points
#     into a coordinate plane, and delete the other coordinates.
#   - add one or more points to make the input full dimensional.
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")
# /var/folders/w_/_4hnpxr91r78y8gdhv58zlrm0000gn/T/ipykernel_3539/4032999566.py:77: UserWarning: Could not compute convex hull for region with 5 points: QH6013 qhull input error: input is less than 2-dimensional since all points have the same x coordinate 0.74
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 341014942  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 0.0078  Error-roundoff 6.3e-16  _one-merge 3.2e-15
#   _near-inside 1.6e-14  Visible-distance 1.3e-15  U-max-coplanar 1.3e-15
#   Width-outside 2.5e-15  _wide-facet 7.6e-15  _maxoutside 3.8e-15
#
#   warnings.warn(f"Could not compute convex hull for region with {len(points)} points: {e}")

# %%
visualize_regions(regions)

# %% [markdown]
# - Woah that's legit -> it't intersting that th emodel is able to learn to "focus on the borders" so much, ya know?
# - That might be interesting to try to undersatnd in the training process.
